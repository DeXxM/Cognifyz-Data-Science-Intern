# %%
import pandas as pd
a=pd.read_csv("Dataset.csv")
print(a.shape)
# Out:
# (9551, 21)

# %% [markdown]
# Task 2: Customer Preference Analysis

# %%
print(a.groupby("Cuisines")["Aggregate rating"].mean())
# Out:
# Cuisines
# Afghani                                      0.725
# Afghani, Mughlai, Chinese                    0.000
# Afghani, North Indian                        0.000
# Afghani, North Indian, Pakistani, Arabian    0.000
# African                                      4.700
#                                              ...
# Western, Asian, Cafe                         4.200
# Western, Fusion, Fast Food                   3.200
# World Cuisine                                4.900
# World Cuisine, Mexican, Italian              4.400
# World Cuisine, Patisserie, Cafe              4.200
# Name: Aggregate rating, Length: 1825, dtype: float64

# %%
print(a.groupby("Cuisines")["Votes"].sum().sort_values(ascending=False))
# Out:
# Cuisines
# North Indian, Mughlai                         53747
# North Indian                                  46241
# North Indian, Chinese                         42012
# Cafe                                          30657
# Chinese                                       21925
#                                               ...
# Fast Food, South Indian, Mithai                   0
# North Indian, Mithai, Chinese                     0
# Mithai, South Indian, Chinese, Street Food        0
# Turkish, Arabian, Moroccan, Lebanese              0
# Tibetan, South Indian, North Indian               0
# Name: Votes, Length: 1825, dtype: int64

# %%
print(a.groupby("Cuisines")["Aggregate rating"].mean().sort_values(ascending=False))
# Out:
# Cuisines
# Burger, Bar Food, Steak                 4.9
# American, Burger, Grill                 4.9
# American, Caribbean, Seafood            4.9
# American, Coffee and Tea                4.9
# Mexican, American, Healthy Food         4.9
#                                        ...
# Tibetan, South Indian, North Indian     0.0
# Afghani, Mughlai, Chinese               0.0
# Tibetan                                 0.0
# Turkish, Arabian, Moroccan, Lebanese    0.0
# Tibetan, Chinese, North Indian          0.0
# Name: Aggregate rating, Length: 1825, dtype: float64
