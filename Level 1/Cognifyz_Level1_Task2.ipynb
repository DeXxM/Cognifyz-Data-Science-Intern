# %%
import pandas as pd

# %%
a=pd.read_csv("Dataset.csv")

# %%
print(a.shape)
# Out:
# (9551, 21)

# %% [markdown]
# Level 1- Task 2: Descriptive Analysis

# %%
print(a.describe())
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# For the next step, I have Written both type of code.
#
# 1st - Combine solution
#
# 2nd - Partvise solution

# %%
#1st -
print(a[["Country Code","City","Cuisines"]].value_counts())
# Out:
# Country Code  City       Cuisines
# 1             New Delhi  North Indian                           658
#                          North Indian, Chinese                  284
#                          Fast Food                              242
#                          Chinese                                228
#                          North Indian, Mughlai                  207
#                                                                ...
# 216           Waterloo   Italian, Pizza, Vegetarian               1
#                          Indian, Middle Eastern                   1
#                          Desserts                                 1
#                          Coffee and Tea, Desserts, Beverages      1
#                          Burger, Pizza, Sandwich                  1
# Name: count, Length: 3024, dtype: int64

# %%
#2nd -
print(a["Country Code"].value_counts())
# Out:
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# 214      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 166      20
# 184      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %%
print(a["City"].value_counts())
# Out:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lakes Entrance       1
# Mohali               1
# Panchkula            1
# Bandung              1
# Randburg             1
# Name: count, Length: 141, dtype: int64

# %%
print(a["Cuisines"].value_counts())
# Out:
# Cuisines
# North Indian                          936
# North Indian, Chinese                 511
# Chinese                               354
# Fast Food                             354
# North Indian, Mughlai                 334
#                                      ...
# World Cuisine, Patisserie, Cafe         1
# Burger, Izgara                          1
# Desserts, B�_rek                        1
# Restaurant Cafe, Turkish, Desserts      1
# Restaurant Cafe, Desserts               1
# Name: count, Length: 1825, dtype: int64

# %%
print(a["Cuisines"].value_counts().head(10))
# Out:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %%
print(a["City"].value_counts().head(10))
# Out:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Lucknow           21
# Ahmedabad         21
# Amritsar          21
# Guwahati          21
# Name: count, dtype: int64
