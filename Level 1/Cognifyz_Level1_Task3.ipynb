# %%
import pandas as pd
a=pd.read_csv("Dataset.csv")
print(a.shape)
# Out:
# (9551, 21)

# %% [markdown]
# Task 3: Geospatial Analysis

# %%
print(a[["Latitude","Longitude"]].head(51))
# took head 50 as unique key
# Out:
#      Latitude   Longitude
# 0   14.565443  121.027535
# 1   14.553708  121.014101
# 2   14.581404  121.056831
# 3   14.585318  121.056475
# 4   14.584450  121.057508
# 5   14.583764  121.056314
# 6   14.531333  120.979667
# 7   14.540000  120.979333
# 8   14.552990  120.980090
# 9   14.572041  121.056532
# 10  14.567689  121.057916
# 11  14.570849  121.060820
# 12  14.649503  121.075419
# 13  14.593450  121.033592
# 14  14.598890  121.038110
# 15  14.237082  121.057040
# 16  14.237679  121.056587
# 17  14.101834  120.951589
# 18  14.554360  121.045878
# 19  14.549337  121.046220
# 20  14.545858  121.053725
# 21  14.545655  121.053500
# 22 -15.764142  -47.881789
# 23 -15.777500  -47.882667
# 24 -15.757472  -47.882136
# 25 -15.758833  -47.888167
# 26 -15.831167  -47.915667
# 27 -15.831000  -47.915667
# 28 -15.820000  -47.907500
# 29 -15.827333  -47.910167
# 30 -15.797000  -47.890167
# 31 -15.831333  -47.923667
# 32 -15.837167  -48.019000
# 33 -15.839775  -48.019092
# ...

# %%
print(a["City"].value_counts())
# Out:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lakes Entrance       1
# Mohali               1
# Panchkula            1
# Bandung              1
# Randburg             1
# Name: count, Length: 141, dtype: int64

# %%
print(a["Country Code"].value_counts())
# Out:
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# 214      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 166      20
# 184      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %%
print(a.groupby("Locality")["Aggregate rating"].mean())
# Out:
# Locality
#  ILD Trade Centre Mall, Sohna Road     3.050000
# 12th Square Building, Banjara Hills    4.300000
# A Hotel, Gurdev Nagar                  3.600000
# ARSS Mall, Paschim Vihar               3.100000
# Aaya Nagar                             0.000000
#                                          ...
# ibis New Delhi, Aerocity               1.550000
# �ayyolu                                4.300000
# �guas Claras                           3.666667
# �ukurambar                             3.400000
# ��mitk�_y                              4.200000
# Name: Aggregate rating, Length: 1208, dtype: float64
