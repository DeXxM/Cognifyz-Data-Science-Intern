# %%
import pandas as pd
a=pd.read_csv("Dataset.csv")
print(a.shape)
# Out:
# (9551, 21)

# %% [markdown]
# Task 3: Feature Engineering

# %%
print(a["Restaurant Name"].str.len().head())
print(a["Address"].str.len().head())
# Out:
# 0    16
# 1    16
# 2    22
# 3     4
# 4    11
# Name: Restaurant Name, dtype: int64
# 0    71
# 1    67
# 2    56
# 3    70
# 4    64
# Name: Address, dtype: int64

# %%
print(a[["Has Table booking", "Has Online delivery"]].replace({"Yes": 1, "No": 0}).head(11))
# Out:
#     Has Table booking  Has Online delivery
# 0                   1                    0
# 1                   1                    0
# 2                   1                    0
# 3                   0                    0
# 4                   1                    0
# 5                   0                    0
# 6                   1                    0
# 7                   1                    0
# 8                   1                    0
# 9                   1                    0
# 10                  0                    0
# /tmp/ipykernel_601/166456782.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   print(a[["Has Table booking", "Has Online delivery"]].replace({"Yes": 1, "No": 0}).head(11))
